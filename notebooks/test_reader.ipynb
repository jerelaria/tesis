# %%
import sys
sys.path.append("../project")  # para poder importar desde medsam_labeler/

import matplotlib.pyplot as plt
from data_io.reader import MedicalImageReader

# %%
reader = MedicalImageReader()
image = reader.load("../data/raw/xray/1256842362861431725328351539259305635_u1qifz.png")

print(f"Shape: {image.volume.shape}")
print(f"Modality: {image.modality}")
print(f"Source: {image.source_path}")
# Out:
# Shape: (1024, 1024, 3)
# Modality: unknown
# Source: ../data/raw/xray/1256842362861431725328351539259305635_u1qifz.png

# %%
plt.figure(figsize=(6, 6))
plt.imshow(image.volume.astype("uint8"))
plt.axis("off")
plt.show()
