# %%
# !git clone https://github.com/facebookresearch/sam3.git
# %cd sam3
# !pip install -e .
# Out:
# fatal: destination path 'sam3' already exists and is not an empty directory.
# /Users/jlguaza/Documents/tesis/sam3
# Obtaining file:///Users/jlguaza/Documents/tesis/sam3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: timm>=1.0.17 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.0.22)
# Requirement already satisfied: numpy==1.26 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.26.0)
# Requirement already satisfied: tqdm in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.67.1)
# Requirement already satisfied: ftfy==6.1.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (6.1.1)
# Requirement already satisfied: regex in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2025.11.3)
# Requirement already satisfied: iopath>=0.1.10 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.10)
# Requirement already satisfied: typing_extensions in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.15.0)
# Requirement already satisfied: huggingface_hub in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.2.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ftfy==6.1.1->sam3==0.1.0) (0.2.14)
# Requirement already satisfied: portalocker in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from iopath>=0.1.10->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: torch in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (2.9.1)
# Requirement already satisfied: torchvision in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.24.1)
# Requirement already satisfied: pyyaml in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.7.0)
# Requirement already satisfied: filelock in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (25.0)
# Requirement already satisfied: shellingham in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (1.5.4)
# Requirement already satisfied: typer-slim in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.20.0)
# Requirement already satisfied: anyio in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (4.12.0)
# Requirement already satisfied: certifi in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (0.16.0)
# Requirement already satisfied: setuptools in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.1.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torchvision->timm>=1.0.17->sam3==0.1.0) (12.0.0)
# Requirement already satisfied: click>=8.0.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from typer-slim->huggingface_hub->sam3==0.1.0) (8.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->timm>=1.0.17->sam3==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from jinja2->torch->timm>=1.0.17->sam3==0.1.0) (3.0.3)
# Building wheels for collected packages: sam3
#   Building editable for sam3 (pyproject.toml) ... done
#   Created wheel for sam3: filename=sam3-0.1.0-0.editable-py3-none-any.whl size=15217 sha256=f7c142263e71cd4993740fc747a5013fb7940edb35da75b054f4e9a7f99cea21
#   Stored in directory: /private/var/folders/2w/cmcnxcbd0pj15jg17hzmbr1r0000gn/T/pip-ephem-wheel-cache-i817e7re/wheels/3c/01/2b/03f04f7b391d3db9c2b295f19c216a09b5cfb32bc5925aa633
# Successfully built sam3
# Installing collected packages: sam3
#   Attempting uninstall: sam3
#     Found existing installation: sam3 0.1.0
#     Uninstalling sam3-0.1.0:
#       Successfully uninstalled sam3-0.1.0
# Successfully installed sam3-0.1.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# For running example notebooks
# !pip install -e ".[notebooks]"

# For development
# !pip install -e ".[train,dev]"
# Out:
# Obtaining file:///Users/jlguaza/Documents/tesis/sam3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: timm>=1.0.17 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.0.22)
# Requirement already satisfied: numpy==1.26 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.26.0)
# Requirement already satisfied: tqdm in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.67.1)
# Requirement already satisfied: ftfy==6.1.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (6.1.1)
# Requirement already satisfied: regex in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2025.11.3)
# Requirement already satisfied: iopath>=0.1.10 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.10)
# Requirement already satisfied: typing_extensions in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.15.0)
# Requirement already satisfied: huggingface_hub in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.2.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ftfy==6.1.1->sam3==0.1.0) (0.2.14)
# Requirement already satisfied: matplotlib in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (3.10.7)
# Requirement already satisfied: jupyter in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.1.1)
# Requirement already satisfied: notebook in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (7.5.0)
# Requirement already satisfied: ipywidgets in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (8.1.8)
# Collecting ipycanvas (from sam3==0.1.0)
#   Using cached ipycanvas-0.14.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting ipympl (from sam3==0.1.0)
#   Using cached ipympl-0.9.8-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pycocotools in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2.0.10)
# INFO: pip is looking at multiple versions of sam3[notebooks] to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement decord; extra == "notebooks" (from sam3[notebooks]) (from versions: none)
# ERROR: No matching distribution found for decord; extra == "notebooks"
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Obtaining file:///Users/jlguaza/Documents/tesis/sam3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: timm>=1.0.17 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.0.22)
# Requirement already satisfied: numpy==1.26 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.26.0)
# Requirement already satisfied: tqdm in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.67.1)
# Requirement already satisfied: ftfy==6.1.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (6.1.1)
# Requirement already satisfied: regex in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2025.11.3)
# Requirement already satisfied: iopath>=0.1.10 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.10)
# Requirement already satisfied: typing_extensions in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.15.0)
# Requirement already satisfied: huggingface_hub in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.2.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ftfy==6.1.1->sam3==0.1.0) (0.2.14)
# Requirement already satisfied: pytest in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (9.0.2)
# Requirement already satisfied: pytest-cov in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (7.0.0)
# Requirement already satisfied: black==24.2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (24.2.0)
# Requirement already satisfied: ufmt==2.8.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2.8.0)
# Requirement already satisfied: ruff-api==0.1.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.0)
# Requirement already satisfied: usort==1.0.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.0.2)
# Requirement already satisfied: gitpython==3.1.31 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (3.1.31)
# Requirement already satisfied: yt-dlp in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2025.12.8)
# Requirement already satisfied: pandas in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2.3.3)
# Requirement already satisfied: opencv-python in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (4.11.0.86)
# Requirement already satisfied: pycocotools in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2.0.10)
# Requirement already satisfied: numba in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.62.1)
# Requirement already satisfied: python-rapidjson in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.23)
# Requirement already satisfied: hydra-core in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.3.2)
# Requirement already satisfied: submitit in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.5.3)
# Requirement already satisfied: tensorboard in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (2.20.0)
# Requirement already satisfied: zstandard in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.25.0)
# Requirement already satisfied: scipy in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.16.3)
# Requirement already satisfied: torchmetrics in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.8.2)
# Requirement already satisfied: fvcore in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.5.post20221221)
# Requirement already satisfied: fairscale in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.4.13)
# Requirement already satisfied: scikit-image in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (0.25.2)
# Requirement already satisfied: scikit-learn in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sam3==0.1.0) (1.7.2)
# Requirement already satisfied: click>=8.0.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from black==24.2.0->sam3==0.1.0) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from black==24.2.0->sam3==0.1.0) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from black==24.2.0->sam3==0.1.0) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from black==24.2.0->sam3==0.1.0) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from black==24.2.0->sam3==0.1.0) (4.5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from gitpython==3.1.31->sam3==0.1.0) (4.0.12)
# Requirement already satisfied: libcst>=0.4.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ufmt==2.8.0->sam3==0.1.0) (1.8.6)
# Requirement already satisfied: moreorless>=0.4.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ufmt==2.8.0->sam3==0.1.0) (0.5.0)
# Requirement already satisfied: tomlkit>=0.7.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ufmt==2.8.0->sam3==0.1.0) (0.13.3)
# Requirement already satisfied: trailrunner>=1.2.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from ufmt==2.8.0->sam3==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=21.2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from usort==1.0.2->sam3==0.1.0) (25.4.0)
# Requirement already satisfied: stdlibs>=2021.4.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from usort==1.0.2->sam3==0.1.0) (2025.10.28)
# Requirement already satisfied: toml>=0.10.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from usort==1.0.2->sam3==0.1.0) (0.10.2)
# Requirement already satisfied: portalocker in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from iopath>=0.1.10->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: torch in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (2.9.1)
# Requirement already satisfied: torchvision in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.24.1)
# Requirement already satisfied: pyyaml in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.7.0)
# Requirement already satisfied: yacs>=0.1.6 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from fvcore->sam3==0.1.0) (0.1.8)
# Requirement already satisfied: termcolor>=1.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from fvcore->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: Pillow in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from fvcore->sam3==0.1.0) (12.0.0)
# Requirement already satisfied: tabulate in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from fvcore->sam3==0.1.0) (0.9.0)
# Requirement already satisfied: filelock in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.28.1)
# Requirement already satisfied: shellingham in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (1.5.4)
# Requirement already satisfied: typer-slim in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.20.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from hydra-core->sam3==0.1.0) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from hydra-core->sam3==0.1.0) (4.9.3)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from numba->sam3==0.1.0) (0.45.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pandas->sam3==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pandas->sam3==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pandas->sam3==0.1.0) (2025.2)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pytest->sam3==0.1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pytest->sam3==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from pytest->sam3==0.1.0) (2.19.2)
# Requirement already satisfied: coverage>=7.10.6 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from coverage[toml]>=7.10.6->pytest-cov->sam3==0.1.0) (7.13.0)
# Requirement already satisfied: networkx>=3.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-image->sam3==0.1.0) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-image->sam3==0.1.0) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-image->sam3==0.1.0) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-image->sam3==0.1.0) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-learn->sam3==0.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from scikit-learn->sam3==0.1.0) (3.6.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from submitit->sam3==0.1.0) (3.1.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (6.33.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (80.9.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from tensorboard->sam3==0.1.0) (3.1.4)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torchmetrics->sam3==0.1.0) (0.15.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython==3.1.31->sam3==0.1.0) (5.0.2)
# Requirement already satisfied: anyio in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (4.12.0)
# Requirement already satisfied: certifi in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->sam3==0.1.0) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->sam3==0.1.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jlguaza/Documents/tesis/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->timm>=1.0.17->sam3==0.1.0) (1.3.0)
# Checking if build backend supports build_editable ... done
# Building wheels for collected packages: sam3
#   Building editable for sam3 (pyproject.toml) ... done
#   Created wheel for sam3: filename=sam3-0.1.0-0.editable-py3-none-any.whl size=15217 sha256=e5c6248d70be791beb76d3045c84d1044c4b95a78193285921dbdf9df403c3e1
#   Stored in directory: /private/var/folders/2w/cmcnxcbd0pj15jg17hzmbr1r0000gn/T/pip-ephem-wheel-cache-2249ugwu/wheels/3c/01/2b/03f04f7b391d3db9c2b295f19c216a09b5cfb32bc5925aa633
# Successfully built sam3
# Installing collected packages: sam3
#   Attempting uninstall: sam3
#     Found existing installation: sam3 0.1.0
#     Uninstalling sam3-0.1.0:
#       Successfully uninstalled sam3-0.1.0
# Successfully installed sam3-0.1.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from huggingface_hub import whoami
print(whoami())
# Out:
# {'type': 'user', 'id': '67ead6eb719fbae9c1cc93c4', 'name': 'jlguaza', 'fullname': 'Jeremias', 'email': 'jeremiaslaria6@gmail.com', 'emailVerified': True, 'canPay': False, 'billingMode': 'postpaid', 'periodEnd': 1767225599, 'isPro': False, 'avatarUrl': '/avatars/e3ea5a33a367688110cafc7c75aa7e55.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'mac', 'role': 'write', 'createdAt': '2025-12-08T21:57:53.223Z'}}}

# %%
import torch
#################################### For Image ####################################
from PIL import Image
from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor

# Load the model
model = build_sam3_image_model()
processor = Sam3Processor(model)
# Load an image
image = Image.open("<YOUR_IMAGE_PATH.jpg>")
inference_state = processor.set_image(image)
# Prompt the model with text
output = processor.set_text_prompt(state=inference_state, prompt="<YOUR_TEXT_PROMPT>")

# Get the masks, bounding boxes, and scores
masks, boxes, scores = output["masks"], output["boxes"], output["scores"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 #################################### For Image ####################################
#       3 from PIL import Image
# ----> 4 from sam3.model_builder import build_sam3_image_model
#       5 from sam3.model.sam3_image_processor import Sam3Processor
#       7 # Load the model
#
# File ~/Documents/tesis/sam3/sam3/__init__.py:3
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates. All Rights Reserved
# ----> 3 from .model_builder import build_sam3_image_model
#       5 __version__ = "0.1.0"
#       7 __all__ = ["build_sam3_image_model"]
#
# File ~/Documents/tesis/sam3/sam3/model_builder.py:33
#      31 from sam3.model.necks import Sam3DualViTDetNeck
#      32 from sam3.model.position_encoding import PositionEmbeddingSine
# ---> 33 from sam3.model.sam1_task_predictor import SAM3InteractiveImagePredictor
#      34 from sam3.model.sam3_image import Sam3Image, Sam3ImageOnVideoMultiGPU
#      35 from sam3.model.sam3_tracking_predictor import Sam3TrackerPredictor
#
# File ~/Documents/tesis/sam3/sam3/model/sam1_task_predictor.py:17
#      14 import torch.nn as nn
#      15 from PIL.Image import Image
# ---> 17 from sam3.model.sam3_tracker_base import Sam3TrackerBase
#      18 from sam3.model.utils.sam1_utils import SAM2Transforms
#      21 # Adapted from https://github.com/facebookresearch/sam2/blob/main/sam2/sam2_image_predictor.py
#
# File ~/Documents/tesis/sam3/sam3/model/sam3_tracker_base.py:10
#       6 import torch.nn.functional as F
#       8 from sam3.model.memory import SimpleMaskEncoder
# ---> 10 from sam3.model.sam3_tracker_utils import get_1d_sine_pe, select_closest_cond_frames
#      12 from sam3.sam.mask_decoder import MaskDecoder, MLP
#      13 from sam3.sam.prompt_encoder import PromptEncoder
#
# File ~/Documents/tesis/sam3/sam3/model/sam3_tracker_utils.py:8
#       5 import torch.nn.functional as F
#       6 from numpy.typing import NDArray
# ----> 8 from sam3.model.edt import edt_triton
#      11 def sample_box_points(
#      12     masks: torch.Tensor,
#      13     noise: float = 0.1,  # SAM default
#    (...)     16     bottom_right_label: int = 3,
#      17 ) -> tuple[NDArray, NDArray]:
#      18     """
#      19     Sample a noised version of the top left and bottom right corners of a given `bbox`
#      20
#    (...)     28     - box_labels: [B, num_pt], label 2 is reserverd for top left and 3 for bottom right corners, dtype=torch.int32
#      29     """
#
# File ~/Documents/tesis/sam3/sam3/model/edt.py:6
#       3 """Triton kernel for euclidean distance transform (EDT)"""
#       5 import torch
# ----> 6 import triton
#       7 import triton.language as tl
#       9 """
#      10 Disclaimer: This implementation is not meant to be extremely efficient. A CUDA kernel would likely be more efficient.
#      11 Even in Triton, there may be more suitable algorithms.
#    (...)     49
#      50 """
#
# ModuleNotFoundError: No module named 'triton'
